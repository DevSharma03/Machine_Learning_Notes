# %% [markdown]
# # Classification – Supervised Machine Learning

# %% [markdown]
# - The classification algorithm is used to identify the category of new observations on the basis of training data.
# - In classification, a program learns from teh given dataset or observations and then classifies new observation into a number of classes or groups.
# - such as, Yes or No, 0 or 1, spam or not spam, cat or dog, etc. classes can be called as targers/labels or categories.
# - Classification is a supervised learning task where the output variable (target) is categorical (e.g., "spam" vs. "not spam", or multiple classes like "cat", "dog", "rabbit").

# %% [markdown]
# ### Types of Classification Algorithms
#
# ##### Binary Classifier
# - If the classification problem has only two possible outcomes, then it is called as Binary Classifier.
# - Example: SPAM or NOT SPAM, CAT or DOG, etc.
#
# ##### Multi-class Classifier
# - If the classification problem has more than two outcomes, then it is called as Multi-class Classifier.
# - Example: Classifications of types of crops, classification of types of music, etc.

# %% [markdown]
# ### Classification Algorithms
#
# | Algorithm                                 | Type              | Notes                          |
# | ----------------------------------------- | ----------------- | ------------------------------ |
# | **Logistic Regression**                   | Linear            | Probabilistic, good baseline   |
# | **K-Nearest Neighbors (KNN)**             | Instance-based  (Non Linear)  | Lazy learner, no training step |
# | **Support Vector Machine**                | Linear/Non-linear | Maximizes margin               |
# | **Decision Tree**                         | Tree-based  (Non Linear)      | Easy to interpret              |
# | **Random Forest**                         | Ensemble   (Non Linear)        | Multiple trees + voting        |
# | **Naive Bayes**                           | Probabilistic  (Non Linear)    | Works well with text, fast     |
# | **Gradient Boosting (XGBoost, LightGBM)** | Ensemble          | Powerful for tabular data      |
# | **Neural Networks**                       | Deep Learning     | Complex patterns, large data   |

# %% [markdown]
# ![image.png](attachment:image.png)
